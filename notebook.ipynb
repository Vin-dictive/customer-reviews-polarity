# %% [markdown]
# # Import Packages

# %%
import pandas as pd
from sklearn.dummy import DummyClassifier
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.model_selection import (
    RandomizedSearchCV,
    GridSearchCV,
)

from sklearn.naive_bayes import BernoulliNB, GaussianNB, MultinomialNB
from sklearn.pipeline import Pipeline, make_pipeline

CHUNK_SIZE = 100000 # Process 50,000 reviews at a time

# %% [markdown]
# # Load the datasets

# %%
train = pd.read_csv('data/train.csv',header=None, encoding='utf-8')
test = pd.read_csv('data/test.csv',header=None, encoding='utf-8')

# %% [markdown]
# Dropped title column because it had null values and does not seem to add anything of value to train the model. Also taking a small chunk from the entire dataset.

# %%
train = train.rename(columns={0:"label",1:"title",2:"content"})
train = train.drop(["title"], axis=1)
train = train[:CHUNK_SIZE]
print(train.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 train = train.rename(columns={0:"label",1:"title",2:"content"})
# ----> 2 train = train.drop(["title"], axis=1)
#       3 train = train[:CHUNK_SIZE]
#       4 print(train.head())
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/generic.py:4807, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4805 for axis, labels in axes.items():
#    4806     if labels is not None:
# -> 4807         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4809 if inplace:
#    4810     self._update_inplace(obj)
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/generic.py:4849, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4847         new_axis = axis.drop(labels, level=level, errors=errors)
#    4848     else:
# -> 4849         new_axis = axis.drop(labels, errors=errors)
#    4850     indexer = axis.get_indexer(new_axis)
#    4852 # Case for non-unique axis
#    4853 else:
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['title'] not found in axis"

# %% [markdown]
# Dropped title column for test dataset as well because it had null values and does not seem to add anything of value to train the model

# %%
test = test.rename(columns={0:"label",1:"title",2:"content"})
test = test.drop(["title"], axis=1)
test
# Out:
#         label                                            content
# 0           2  My lovely Pat has one of the GREAT voices of h...
# 1           2  Despite the fact that I have only played a sma...
# 2           1  I bought this charger in Jul 2003 and it worke...
# 3           2  Check out Maha Energy's website. Their Powerex...
# 4           2  Reviewed quite a bit of the combo players and ...
# ...       ...                                                ...
# 399995      1  We bought this Thomas for our son who is a hug...
# 399996      1  My son recieved this as a birthday gift 2 mont...
# 399997      1  I bought this toy for my son who loves the "Th...
# 399998      2  This is a compilation of a wide range of Mitfo...
# 399999      1  This DVD will be a disappointment if you get i...
#
# [400000 rows x 2 columns]

# %%
train.isnull().sum()
# Out:
# label      0
# content    0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# label      0
# content    0
# dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   label    100000 non-null  int64
#  1   content  100000 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# Checking if there is huge disparity in the label column for the two categorical values because this can cause problems when using Naive Bayes. There is no disparity between label 1 and 2 in the chunk I have taken

# %%
train['label'].value_counts()
# Out:
# label
# 2    51267
# 1    48733
# Name: count, dtype: int64

# %% [markdown]
# # Taking the test and train df separately

# %%
X_train, y_train = train["content"], train["label"]
X_test, y_test = test["content"], test["label"]

# %% [markdown]
# Run the countVectoriser thru pipeline and then BernoulliNB

# %%
pipe_nb = Pipeline([
    # This step will be replaced by either CountVectorizer or TfidfVectorizer
    ('vectorizer', CountVectorizer()), 
    ('nb', BernoulliNB(alpha=1))
])

# Define the Expanded Parameter Grid:
param_grid = [
    # --- Option 1: Tune CountVectorizer ---
    {
        'vectorizer': [CountVectorizer(stop_words='english', binary=True)], # Use binary=True for BernoulliNB
        'vectorizer__max_features': [5000, 10000, 20000],
        'nb__alpha': [0.1, 1.0, 5.0]
    },
    
    # --- Option 2: Tune TfidfVectorizer ---
    {
        'vectorizer': [TfidfVectorizer(stop_words='english', binary=True)], # Also use binary=True
        'vectorizer__max_features': [5000, 10000, 20000],
        'vectorizer__ngram_range': [(1, 1), (1, 2)], # Test unigrams vs. unigrams+bigrams
        'nb__alpha': [0.1, 1.0, 5.0]
    }
]

search = GridSearchCV(
    pipe_nb, 
    param_grid,
    n_jobs=-1, 
    scoring='accuracy', 
    return_train_score=True,
    verbose=2
)

search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.2s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.4s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.4s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.5s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.2s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.0s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.1s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.4s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.4s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.4s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.4s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.6s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.6s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.3s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.0s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.2s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.2s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.2s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.3s
# [CV] END nb__alpha=1.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.5s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000; total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.2s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.5s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=CountVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000; total time=   3.3s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.4s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.1s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.2s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.2s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.7s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  11.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.7s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   4.1s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.9s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  14.0s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   4.3s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  14.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.9s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  13.1s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  13.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  13.2s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   4.1s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.8s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   4.0s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.1s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.0s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.6s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.6s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.4s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.2s
# [CV] END nb__alpha=0.1, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.5s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.0s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.8s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.8s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  12.2s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.1s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.3s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  12.7s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  13.2s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  13.1s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.7s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  13.1s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  12.6s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  12.6s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.4s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  11.7s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.4s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.8s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  11.8s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.0s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.4s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.9s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.6s
# [CV] END nb__alpha=1.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  12.9s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.0s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.8s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   4.5s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  13.0s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.5s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  13.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 1); total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  13.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  13.1s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=5000, vectorizer__ngram_range=(1, 2); total time=  12.9s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.2s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  10.6s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  10.8s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.6s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 1); total time=   3.7s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  11.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  11.4s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=10000, vectorizer__ngram_range=(1, 2); total time=  11.6s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  10.4s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  10.2s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  10.3s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=  10.2s
# [CV] END nb__alpha=5.0, vectorizer=TfidfVectorizer(binary=True, stop_words='english'), vectorizer__max_features=20000, vectorizer__ngram_range=(1, 2); total time=   9.7s
# GridSearchCV(estimator=Pipeline(steps=[('vectorizer', CountVectorizer()),
#                                        ('nb', BernoulliNB(alpha=1))]),
#              n_jobs=-1,
#              param_grid=[{'nb__alpha': [0.1, 1.0, 5.0],
#                           'vectorizer': [CountVectorizer(binary=True,
#                                                          stop_words='english')],
#                           'vectorizer__max_features': [5000, 10000, 20000]},
#                          {'nb__alpha': [0.1, 1.0, 5.0],
#                           'vectorizer': [TfidfVectorizer(binary=True,
#                                                          stop_words='english')],
#                           'vectorizer__max_features': [5000, 10000, 20000],
#                           'vectorizer__ngram_range': [(1, 1), (1, 2)]}],
#              return_train_score=True, scoring='accuracy', verbose=2)

# %%
results = pd.DataFrame(search.cv_results_)

# 2. Find the index of the best score
best_index = search.best_index_

# 3. Extract key details for the best model configuration
best_model_details = {
    "Best Parameters": search.best_params_,
    "Best CV Score (Mean Validation)": search.best_score_,
    "Mean Training Score": results.loc[best_index, 'mean_train_score'],
    "Std Dev CV Score": results.loc[best_index, 'std_test_score'],
    "Std Dev Training Score": results.loc[best_index, 'std_train_score'],
    "Vectorization Method Used": search.best_params_['nb__alpha'], # Alpha doesn't identify the vectorizer, so we rely on the pipeline structure.
    "Best Alpha (Smoothing)": search.best_params_['nb__alpha']
}

print("--- Best Model Configuration ---")
for key, value in best_model_details.items():
    if isinstance(value, float):
        print(f"**{key}**: {value:.4f}")
    else:
        print(f"**{key}**: {value}")

# 4. (Optional) Display a summary table of the top 3 results
print("\n--- Top 3 Model Configurations ---")
top_3_results = results.sort_values('rank_test_score').head(3)

# Display relevant columns
summary = top_3_results[['params', 'mean_train_score', 'mean_test_score', 'rank_test_score']]
summary.columns = ['Parameters', 'Mean Train Accuracy', 'Mean CV Accuracy', 'Rank']
print(summary)
# Out:
# --- Best Model Configuration ---
# **Best Parameters**: {'nb__alpha': 0.1, 'vectorizer': TfidfVectorizer(binary=True, stop_words='english'), 'vectorizer__max_features': 20000, 'vectorizer__ngram_range': (1, 2)}
# **Best CV Score (Mean Validation)**: 0.8399
# **Mean Training Score**: 0.8634
# **Std Dev CV Score**: 0.0035
# **Std Dev Training Score**: 0.0008
# **Vectorization Method Used**: 0.1000
# **Best Alpha (Smoothing)**: 0.1000
#
# --- Top 3 Model Configurations ---
#                                            Parameters  Mean Train Accuracy  \
# 14  {'nb__alpha': 0.1, 'vectorizer': TfidfVectoriz...             0.863410
# 20  {'nb__alpha': 1.0, 'vectorizer': TfidfVectoriz...             0.861962
# 26  {'nb__alpha': 5.0, 'vectorizer': TfidfVectoriz...             0.857272
#
#     Mean CV Accuracy  Rank
# 14           0.83986     1
# 20           0.83941     2
# 26           0.83732     3

# %%
from sklearn.metrics import classification_report, accuracy_score


final_model = search.best_estimator_

X_test, y_test = test["content"], test["label"]

y_prediction = final_model.predict(X_test)

final_accuracy = accuracy_score(y_test, y_prediction)

final_report = classification_report(y_test, y_prediction)

print("Final Model Evaluation on External Test Dataset (test.csv) ---")
print(f"Total Test Reviews: {len(X_test)}")
print(f"Final Test Accuracy: {final_accuracy:.4f}")
print("\nClassification Report (Labels 1 and 2):")
print(final_report)
# Out:
# Final Model Evaluation on External Test Dataset (test.csv) ---
# Total Test Reviews: 400000
# Final Test Accuracy: 0.8387
#
# Classification Report (Labels 1 and 2):
#               precision    recall  f1-score   support
#
#            1       0.85      0.83      0.84    200000
#            2       0.83      0.85      0.84    200000
#
#     accuracy                           0.84    400000
#    macro avg       0.84      0.84      0.84    400000
# weighted avg       0.84      0.84      0.84    400000
